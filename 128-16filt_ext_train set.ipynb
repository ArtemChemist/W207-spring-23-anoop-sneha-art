# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import cv2
import csv
from keras.models import Model, Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from keras.layers.normalization import batch_normalization
import os
import seaborn as sns
from datetime import datetime
# Out:
# 2023-04-07 16:55:09.416088: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Set up folder
SIZE = 128 #Size of the images this model will deal with
IMDIM = 1
Filters = 16

# %%
# Set up folder, unless it is already set up
p = os.path.abspath('.')
resized_dir = os.path.join(p, f'{SIZE}')
if not os.path.exists(resized_dir):
    os.mkdir(resized_dir)
    print(f"{resized_dir} created")
else:
    print(f"{resized_dir} already exists")

# Resize images and write them into folder, unless they are alrady there
for file in glob.glob('./Thresholded/*'):
	filename = file.split('/')[-1]
	new_name = os.path.join(resized_dir, filename)
	if not os.path.exists(new_name):
		img = cv2.imread(file, cv2.IMREAD_COLOR)
		img = cv2.resize(img, (SIZE,SIZE))
		cv2.imwrite(new_name, img)

# Read filenames in the folder
image_names = []
labels = []

for file in glob.glob(f'{resized_dir}/*.jpg'):
	filename = file.split('/')[-1]
	num_colonies = int(filename.split('-')[2].strip().split('.')[0])
	if num_colonies == 0:
		labels.append(0)
	else:
		labels.append(1)
	image_names.append(filename)

image_names = np.array(image_names) #  Array with image nbames
labels = np.array(labels)			#  Array with binary labels

#  Make two arrays with filenames: one for positive and one for negative images
pos_im_files = [image_names[i] for i in range(image_names.shape[0]) if labels[i]]
pos_im_files = np.array(pos_im_files)
neg_im_files = [image_names[i] for i in range(image_names.shape[0]) if not labels[i]]
neg_im_files = np.array(neg_im_files)
num_pos = pos_im_files.shape[0]
num_neg = neg_im_files.shape[0]
print(f'Full dataset: {num_pos} images with bacteria and {num_neg} without')

#  There are ~10x positive than negative.
#  For initital training let's get all positive and equal number of negative
#  For that:
#  (1) Index files of randomly selected negative images
np.random.seed(0) # For reproducibility
idx = np.random.choice(np.arange(neg_im_files.shape[0]), 3*num_pos, replace = False)
#  (2) Apply this index to the array of image names
neg_selected_files = neg_im_files[idx]
print(f"{pos_im_files.shape[0]}pos selected and {neg_selected_files.shape[0]} negative selected")
# Out:
# /home/art_usr/source_code/CFU_counter/128 already exists
# Full dataset: 315 images with bacteria and 3428 without
# 315pos selected and 945 negative selected

# %%
# Read the positive files, only red channel
# Also add flipped image
print("Reading positive images...")
images = []
new_labels = []
for file_name in pos_im_files:
    file = os.path.join(resized_dir, file_name)
    img = cv2.imread(file, cv2.IMREAD_COLOR)
    images.append(img[:,:,2])
    new_labels.append(1)
    img_flipped_vert = cv2.flip(img[:,:,2], 0)
    images.append(img_flipped_vert)
    new_labels.append(1)
    img_flipped_hor = cv2.flip(img[:,:,2], 1)
    images.append(img_flipped_hor)
    new_labels.append(1)

print("Reading negative images...")
for file_name in neg_selected_files:
    file = os.path.join(resized_dir, file_name)
    img = cv2.imread(file, cv2.IMREAD_COLOR)
    images.append(img[:,:,2])
    new_labels.append(0)

images = np.array(images)
new_labels = np.array(new_labels)

# Now shuffle the images and labels
print("Suffling the dataset ....")
num_datapoints = images.shape[0]
indices = np.arange(num_datapoints)
shuffled_indices = np.random.permutation(indices)
X_shuffled = images[shuffled_indices]
y_shuffled = new_labels[shuffled_indices]

#  Make array shape compatible with keras Conv2D layers
X_shuffled = X_shuffled.reshape(X_shuffled.shape[0], X_shuffled.shape[1], X_shuffled.shape[2], 1)
X_shuffled = X_shuffled/255 # Scale all images

# Split into test and train. 
# Rely on random shuffling, can just take first 70% for train
print("Splitting to train/test 70/30")
num_train = int(num_datapoints*0.7)

x_train = X_shuffled[ :num_train, :, :, :]
y_train = y_shuffled[ :num_train]
x_test = X_shuffled[num_train: , :, :, :]
y_test = y_shuffled[num_train:]

print(f'Set shape: train-> {x_train.shape}, test ->{x_test.shape}')
# Out:
# Reading positive images...
# Reading negative images...
# Suffling the dataset ....
# Splitting to train/test 70/30
# Set shape: train-> (1323, 128, 128, 1), test ->(567, 128, 128, 1)

# %%
# Visualize first 25 images to make sure it makes sense
fig, axs = plt.subplots(nrows=5, ncols=5, figsize=(12,12))

for i, j in [(i,j) for i in np.arange(5) for j in np.arange(5)]:
    idx = 5*i+j
    image = x_train[idx]
    axs[i,j].imshow(image)
    axs[i,j].set_title(y_train[idx])
    axs[i,j].axis('off')

plt.show()

# %%
#Make convolutional layers

kernels = [ (np.max([int(SIZE*fraction), 3]),np.max([int(SIZE*fraction), 3])) for fraction in (0.01, 0.02, 0.04, 0.06)]

activation = 'sigmoid'

feature_extractor = Sequential()
feature_extractor.add(Conv2D(Filters , kernels[0], activation = activation, padding = 'same', input_shape = (SIZE, SIZE, IMDIM), data_format="channels_last"))
feature_extractor.add(batch_normalization.BatchNormalization())

for kernel in kernels[1:]:
    print(kernel)
    feature_extractor.add(Conv2D(Filters , kernel, activation = activation, padding = 'same', kernel_initializer = 'he_uniform'))
    feature_extractor.add(batch_normalization.BatchNormalization())
    feature_extractor.add(MaxPooling2D())

feature_extractor.add(Flatten())

#Add layers for deep learning prediction
x = feature_extractor.output  
x = Dense(128, activation = activation, kernel_initializer = 'he_uniform')(x)
prediction_layer = Dense(2, activation = 'softmax')(x)

# Make a new model combining both feature extractor and x
cnn_model = Model(inputs=feature_extractor.input, outputs=prediction_layer)
cnn_model.compile(optimizer='rmsprop',loss = 'categorical_crossentropy', metrics = ['accuracy'])
print(cnn_model.summary())
# Out:
# 2023-04-07 16:55:43.865072: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-07 16:55:43.866460: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# (3, 3)
# (5, 5)
# (7, 7)
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_input (InputLayer)   [(None, 128, 128, 1)]     0
#
#  conv2d (Conv2D)             (None, 128, 128, 16)      160
#
#  batch_normalization (BatchN  (None, 128, 128, 16)     64
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 16)      2320
#
#  batch_normalization_1 (Batc  (None, 128, 128, 16)     64
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 16)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 16)        6416
#
#  batch_normalization_2 (Batc  (None, 64, 64, 16)       64
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 16)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 16)        12560
#
#  batch_normalization_3 (Batc  (None, 32, 32, 16)       64
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 128)               524416
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 546,386
# Trainable params: 546,258
# Non-trainable params: 128
# _________________________________________________________________
# None

# %%
from tensorflow.keras.callbacks import Callback

class EarlyStoppingAtAccuracy(Callback):
    def __init__(self, threshold, acc_hist):
        super(EarlyStoppingAtAccuracy, self).__init__()
        self.threshold = threshold
        self.acc_hist = acc_hist

    def on_epoch_end(self, epoch, logs=None):
        val_accuracy = logs.get("val_accuracy")
        self.acc_hist.append(val_accuracy)
        if len(self.acc_hist) > 3 and np.median(self.acc_hist[-3:]) >= self.threshold:
            self.model.stop_training = True
            print(f"\nStopping training: Validation accuracy reached {self.threshold:.2f}")

# Set the desired accuracy threshold
accuracy_threshold = 0.9
acc_hist = []

# Create the early stopping callback
early_stopping = EarlyStoppingAtAccuracy(accuracy_threshold, acc_hist )


#Convert y to one hot encoding for use in CNN 
from keras.utils import to_categorical
y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)

# Train CNN model
history = cnn_model.fit(x_train, y_train_one_hot, epochs=100, validation_data = (x_test, y_test_one_hot), callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 42/42 [==============================] - 40s 921ms/step - loss: 0.8557 - accuracy: 0.6636 - val_loss: 3.4174 - val_accuracy: 0.4921
# Epoch 2/100
# 42/42 [==============================] - 39s 943ms/step - loss: 0.4812 - accuracy: 0.7876 - val_loss: 3.0569 - val_accuracy: 0.4921
# Epoch 3/100
# 42/42 [==============================] - 38s 911ms/step - loss: 0.4153 - accuracy: 0.8201 - val_loss: 3.4973 - val_accuracy: 0.4921
# Epoch 4/100
# 42/42 [==============================] - 39s 934ms/step - loss: 0.3903 - accuracy: 0.8314 - val_loss: 2.6685 - val_accuracy: 0.4921
# Epoch 5/100
# 42/42 [==============================] - 39s 932ms/step - loss: 0.3325 - accuracy: 0.8624 - val_loss: 1.6985 - val_accuracy: 0.4921
# Epoch 6/100
# 42/42 [==============================] - 39s 939ms/step - loss: 0.2909 - accuracy: 0.8730 - val_loss: 3.3894 - val_accuracy: 0.5079
# Epoch 7/100
# 42/42 [==============================] - 40s 954ms/step - loss: 0.2654 - accuracy: 0.8896 - val_loss: 4.3617 - val_accuracy: 0.5079
# Epoch 8/100
# 42/42 [==============================] - 40s 946ms/step - loss: 0.2118 - accuracy: 0.9153 - val_loss: 4.5918 - val_accuracy: 0.5079
# Epoch 9/100
# 42/42 [==============================] - 39s 933ms/step - loss: 0.2143 - accuracy: 0.9161 - val_loss: 4.4775 - val_accuracy: 0.5097
# Epoch 10/100
# 42/42 [==============================] - 39s 933ms/step - loss: 0.1787 - accuracy: 0.9350 - val_loss: 5.2761 - val_accuracy: 0.5079
# Epoch 11/100
# 42/42 [==============================] - 39s 943ms/step - loss: 0.1684 - accuracy: 0.9327 - val_loss: 3.8325 - val_accuracy: 0.5256
# Epoch 12/100
# 42/42 [==============================] - 39s 941ms/step - loss: 0.1661 - accuracy: 0.9410 - val_loss: 0.4789 - val_accuracy: 0.8413
# Epoch 13/100
# 42/42 [==============================] - 39s 936ms/step - loss: 0.1389 - accuracy: 0.9471 - val_loss: 2.7420 - val_accuracy: 0.5538
# Epoch 14/100
# 42/42 [==============================] - 39s 928ms/step - loss: 0.1042 - accuracy: 0.9652 - val_loss: 1.8434 - val_accuracy: 0.6120
# Epoch 15/100
# 42/42 [==============================] - 40s 945ms/step - loss: 0.0745 - accuracy: 0.9803 - val_loss: 2.1627 - val_accuracy: 0.5944
# Epoch 16/100
# 42/42 [==============================] - 39s 936ms/step - loss: 0.0895 - accuracy: 0.9728 - val_loss: 1.4429 - val_accuracy: 0.6896
# Epoch 17/100
# 42/42 [==============================] - 40s 949ms/step - loss: 0.0768 - accuracy: 0.9743 - val_loss: 2.6780 - val_accuracy: 0.6032
# Epoch 18/100
# 42/42 [==============================] - 40s 963ms/step - loss: 0.0644 - accuracy: 0.9766 - val_loss: 2.6425 - val_accuracy: 0.5891
# Epoch 19/100
# 42/42 [==============================] - 41s 983ms/step - loss: 0.0305 - accuracy: 0.9909 - val_loss: 0.5732 - val_accuracy: 0.8607
# Epoch 20/100
# 42/42 [==============================] - 41s 981ms/step - loss: 0.0614 - accuracy: 0.9758 - val_loss: 1.0081 - val_accuracy: 0.7972
# Epoch 21/100
# 42/42 [==============================] - 40s 958ms/step - loss: 0.0209 - accuracy: 0.9970 - val_loss: 1.3959 - val_accuracy: 0.7407
# Epoch 22/100
# 42/42 [==============================] - 41s 971ms/step - loss: 0.0362 - accuracy: 0.9887 - val_loss: 3.9652 - val_accuracy: 0.5891
# Epoch 23/100
# 42/42 [==============================] - 42s 1s/step - loss: 0.0163 - accuracy: 0.9940 - val_loss: 1.1149 - val_accuracy: 0.7989
# Epoch 24/100
# 42/42 [==============================] - 42s 1s/step - loss: 0.0948 - accuracy: 0.9803 - val_loss: 0.7619 - val_accuracy: 0.8377
# Epoch 25/100
# 42/42 [==============================] - 41s 982ms/step - loss: 0.0057 - accuracy: 0.9992 - val_loss: 0.8235 - val_accuracy: 0.8483
# Epoch 26/100
# 42/42 [==============================] - 42s 994ms/step - loss: 0.1008 - accuracy: 0.9826 - val_loss: 1.0975 - val_accuracy: 0.8042
# Epoch 27/100
# 42/42 [==============================] - 41s 976ms/step - loss: 0.0099 - accuracy: 0.9962 - val_loss: 1.2364 - val_accuracy: 0.8025
# Epoch 28/100
# 42/42 [==============================] - 42s 1s/step - loss: 0.0752 - accuracy: 0.9803 - val_loss: 1.0201 - val_accuracy: 0.8360
# Epoch 29/100
# 42/42 [==============================] - 42s 1s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 1.0630 - val_accuracy: 0.8466
# Epoch 30/100
# 42/42 [==============================] - 41s 979ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.8482 - val_accuracy: 0.8748
# Epoch 31/100
# 42/42 [==============================] - 41s 984ms/step - loss: 0.0944 - accuracy: 0.9826 - val_loss: 2.1668 - val_accuracy: 0.6825
# Epoch 32/100
# 42/42 [==============================] - 42s 1s/step - loss: 9.7057e-04 - accuracy: 1.0000 - val_loss: 1.3043 - val_accuracy: 0.8272
# Epoch 33/100
# 42/42 [==============================] - 43s 1s/step - loss: 0.0218 - accuracy: 0.9940 - val_loss: 0.8204 - val_accuracy: 0.8695
# Epoch 34/100
# 42/42 [==============================] - 42s 1s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.6885 - val_accuracy: 0.8889
# Epoch 35/100
# 42/42 [==============================] - 42s 997ms/step - loss: 0.0190 - accuracy: 0.9947 - val_loss: 1.0821 - val_accuracy: 0.8395
# Epoch 36/100
# 42/42 [==============================] - 42s 1s/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.9882 - val_accuracy: 0.8413
# Epoch 37/100
# 42/42 [==============================] - 42s 992ms/step - loss: 0.0055 - accuracy: 0.9985 - val_loss: 0.8464 - val_accuracy: 0.8713
# Epoch 38/100
# 42/42 [==============================] - 43s 1s/step - loss: 0.0199 - accuracy: 0.9947 - val_loss: 0.5496 - val_accuracy: 0.8783
# Epoch 39/100
# 42/42 [==============================] - 42s 1s/step - loss: 0.0376 - accuracy: 0.9902 - val_loss: 0.9993 - val_accuracy: 0.8466
# Epoch 40/100
# 42/42 [==============================] - 42s 1s/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.8938 - val_accuracy: 0.8783
# Epoch 41/100
# 42/42 [==============================] - 42s 1s/step - loss: 2.2194e-04 - accuracy: 1.0000 - val_loss: 0.9067 - val_accuracy: 0.8801
# Epoch 42/100
# 42/42 [==============================] - 42s 997ms/step - loss: 0.0195 - accuracy: 0.9940 - val_loss: 1.1994 - val_accuracy: 0.8289
# Epoch 43/100
# 42/42 [==============================] - 41s 984ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 1.2402 - val_accuracy: 0.8448
# Epoch 44/100
# 42/42 [==============================] - 41s 991ms/step - loss: 0.0135 - accuracy: 0.9962 - val_loss: 1.5550 - val_accuracy: 0.8042
# Epoch 45/100
# 42/42 [==============================] - 42s 1s/step - loss: 0.0168 - accuracy: 0.9924 - val_loss: 0.7713 - val_accuracy: 0.8871
# Epoch 46/100
# 42/42 [==============================] - 42s 1s/step - loss: 1.7242e-04 - accuracy: 1.0000 - val_loss: 0.7427 - val_accuracy: 0.8959
# Epoch 47/100
# 42/42 [==============================] - 42s 1s/step - loss: 0.0122 - accuracy: 0.9985 - val_loss: 0.9017 - val_accuracy: 0.8730
# Epoch 48/100
# 42/42 [==============================] - 42s 1s/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.7969 - val_accuracy: 0.8818
# Epoch 49/100
# 42/42 [==============================] - 43s 1s/step - loss: 0.0088 - accuracy: 0.9962 - val_loss: 0.6638 - val_accuracy: 0.8536
# Epoch 50/100
# 42/42 [==============================] - 42s 1s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.5267 - val_accuracy: 0.8272
# Epoch 51/100
# 42/42 [==============================] - 42s 1s/step - loss: 1.5015e-04 - accuracy: 1.0000 - val_loss: 1.0988 - val_accuracy: 0.8642
# Epoch 52/100
# 42/42 [==============================] - 43s 1s/step - loss: 3.2232e-05 - accuracy: 1.0000 - val_loss: 0.8188 - val_accuracy: 0.8942
# Epoch 53/100
# 42/42 [==============================] - 43s 1s/step - loss: 0.0094 - accuracy: 0.9962 - val_loss: 0.6149 - val_accuracy: 0.8836
# Epoch 54/100
# 42/42 [==============================] - 42s 1s/step - loss: 0.0074 - accuracy: 0.9985 - val_loss: 1.3316 - val_accuracy: 0.8395
# Epoch 55/100
# 42/42 [==============================] - 42s 1s/step - loss: 2.3756e-04 - accuracy: 1.0000 - val_loss: 0.8815 - val_accuracy: 0.8942
# Epoch 56/100
# 42/42 [==============================] - 43s 1s/step - loss: 2.4822e-05 - accuracy: 1.0000 - val_loss: 0.8319 - val_accuracy: 0.9012
# Epoch 57/100
# 42/42 [==============================] - 42s 1s/step - loss: 0.0013 - accuracy: 0.9992 - val_loss: 0.9300 - val_accuracy: 0.8748
# Epoch 58/100
# 42/42 [==============================] - 43s 1s/step - loss: 0.0163 - accuracy: 0.9962 - val_loss: 1.2135 - val_accuracy: 0.8571
# Epoch 59/100
# 42/42 [==============================] - 42s 1s/step - loss: 1.3198e-04 - accuracy: 1.0000 - val_loss: 1.0742 - val_accuracy: 0.8765
# Epoch 60/100
# 42/42 [==============================] - 43s 1s/step - loss: 1.6751e-05 - accuracy: 1.0000 - val_loss: 0.8739 - val_accuracy: 0.8924
# Epoch 61/100
# 42/42 [==============================] - 42s 1s/step - loss: 0.0099 - accuracy: 0.9962 - val_loss: 0.7750 - val_accuracy: 0.8907
# Epoch 62/100
# 42/42 [==============================] - 44s 1s/step - loss: 7.3314e-05 - accuracy: 1.0000 - val_loss: 0.7702 - val_accuracy: 0.8889
# Epoch 63/100
# 42/42 [==============================] - 43s 1s/step - loss: 1.3168e-05 - accuracy: 1.0000 - val_loss: 0.7761 - val_accuracy: 0.8977
# Epoch 64/100
# 42/42 [==============================] - 42s 1s/step - loss: 5.0600e-06 - accuracy: 1.0000 - val_loss: 0.7534 - val_accuracy: 0.8995
# Epoch 65/100
# 42/42 [==============================] - 43s 1s/step - loss: 0.0041 - accuracy: 0.9992 - val_loss: 0.7971 - val_accuracy: 0.8660
# Epoch 66/100
# 42/42 [==============================] - 43s 1s/step - loss: 1.6301e-04 - accuracy: 1.0000 - val_loss: 0.7539 - val_accuracy: 0.8765
# Epoch 67/100
# 42/42 [==============================] - 42s 996ms/step - loss: 9.2405e-06 - accuracy: 1.0000 - val_loss: 0.7933 - val_accuracy: 0.8889
# Epoch 68/100
# 42/42 [==============================] - 43s 1s/step - loss: 0.0263 - accuracy: 0.9940 - val_loss: 1.1524 - val_accuracy: 0.8695
# Epoch 69/100
# 42/42 [==============================] - 42s 1s/step - loss: 2.2894e-04 - accuracy: 1.0000 - val_loss: 0.7725 - val_accuracy: 0.9012
# Epoch 70/100
# 42/42 [==============================] - 42s 1s/step - loss: 4.4726e-05 - accuracy: 1.0000 - val_loss: 1.0262 - val_accuracy: 0.8836
# Epoch 71/100
# 42/42 [==============================] - 42s 1s/step - loss: 2.1480e-05 - accuracy: 1.0000 - val_loss: 1.1660 - val_accuracy: 0.8871
# Epoch 72/100
# 42/42 [==============================] - 42s 1s/step - loss: 1.5746e-06 - accuracy: 1.0000 - val_loss: 0.9086 - val_accuracy: 0.8924
# Epoch 73/100
# 42/42 [==============================] - 43s 1s/step - loss: 0.0384 - accuracy: 0.9917 - val_loss: 0.9807 - val_accuracy: 0.8783
# Epoch 74/100
# 42/42 [==============================] - 42s 1s/step - loss: 1.4919e-04 - accuracy: 1.0000 - val_loss: 0.8048 - val_accuracy: 0.8818
# Epoch 75/100
# 42/42 [==============================] - 42s 1s/step - loss: 1.2562e-05 - accuracy: 1.0000 - val_loss: 0.8655 - val_accuracy: 0.8924
# Epoch 76/100
# 42/42 [==============================] - 42s 1s/step - loss: 2.1614e-06 - accuracy: 1.0000 - val_loss: 0.8604 - val_accuracy: 0.8995
# Epoch 77/100
# 42/42 [==============================] - 42s 1s/step - loss: 8.3455e-07 - accuracy: 1.0000 - val_loss: 0.8885 - val_accuracy: 0.8977
# Epoch 78/100
# 42/42 [==============================] - 42s 1s/step - loss: 0.0264 - accuracy: 0.9924 - val_loss: 0.9519 - val_accuracy: 0.8660
# Epoch 79/100
# 42/42 [==============================] - 42s 1s/step - loss: 7.0784e-05 - accuracy: 1.0000 - val_loss: 0.9400 - val_accuracy: 0.8395
# Epoch 80/100
# 42/42 [==============================] - 43s 1s/step - loss: 1.4295e-05 - accuracy: 1.0000 - val_loss: 0.9056 - val_accuracy: 0.8642
# Epoch 81/100
# 42/42 [==============================] - 42s 1s/step - loss: 3.2815e-06 - accuracy: 1.0000 - val_loss: 0.9408 - val_accuracy: 0.8818
# Epoch 82/100
# 42/42 [==============================] - 43s 1s/step - loss: 8.4499e-07 - accuracy: 1.0000 - val_loss: 0.9844 - val_accuracy: 0.8889
# Epoch 83/100
# 42/42 [==============================] - 42s 1s/step - loss: 5.9071e-07 - accuracy: 1.0000 - val_loss: 0.9275 - val_accuracy: 0.8854
# Epoch 84/100
# 42/42 [==============================] - 42s 1s/step - loss: 0.0170 - accuracy: 0.9955 - val_loss: 1.2658 - val_accuracy: 0.8889
# Epoch 85/100
# 42/42 [==============================] - 43s 1s/step - loss: 2.0203e-05 - accuracy: 1.0000 - val_loss: 1.0869 - val_accuracy: 0.9012
# Epoch 86/100
# 42/42 [==============================] - 43s 1s/step - loss: 3.6867e-06 - accuracy: 1.0000 - val_loss: 0.9349 - val_accuracy: 0.8995
# Epoch 87/100
# 42/42 [==============================] - ETA: 0s - loss: 6.4506e-07 - accuracy: 1.0000
# Stopping training: Validation accuracy reached 0.90
# 42/42 [==============================] - 42s 1s/step - loss: 6.4506e-07 - accuracy: 1.0000 - val_loss: 0.9922 - val_accuracy: 0.9030

# %%
# Set up folder, unless it is already set up


now = datetime.now() # current date and time

date_time = now.strftime("%m-%d-%Y-%H-%M")
p = os.path.abspath('.')
model_dir = os.path.join(resized_dir, f'res_{SIZE}_num_flt_{Filters}_model')
if not os.path.exists(model_dir):
    os.mkdir(model_dir)
    print(f"{model_dir} created")
else:
    print(f"{model_dir} already exists")
    model_dir = model_dir+date_time

cnn_model.save(model_dir)

# Save history into a csv
with open(os.path.join(model_dir, 'hist.csv'), 'w+') as file:
  csvwriter = csv.writer(file)
  csvwriter.writerow('val_loss')
  csvwriter.writerow(history.history['val_loss'])
  csvwriter.writerow('loss')
  csvwriter.writerow(history.history['loss'])
  csvwriter.writerow('val_accuracy')
  csvwriter.writerow(history.history['val_accuracy'])
  csvwriter.writerow('accuracy')
  csvwriter.writerow(history.history['accuracy'])
# Out:
# /home/art_usr/source_code/CFU_counter/128/res_128_num_flt_16_model already exists
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/art_usr/source_code/CFU_counter/128/res_128_num_flt_16_model04-07-2023-19-08/assets
# INFO:tensorflow:Assets written to: /home/art_usr/source_code/CFU_counter/128/res_128_num_flt_16_model04-07-2023-19-08/assets

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12,6))
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
axs[0].set_title('Loss')
axs[0].scatter(epochs, loss, label = 'Training loss')
axs[0].scatter(epochs, val_loss, label = 'Validation loss')
axs[0].legend()
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Loss')
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
axs[1].set_title('Accuracy')
axs[1].scatter(epochs, accuracy, label = 'Training accuracy')
axs[1].scatter(epochs, val_accuracy, label = 'Validation accuracy')
axs[1].legend()
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Loss')


plt.show()

# %%
prediction_NN = cnn_model.predict(x_test)
prediction_NN = np.argmax(prediction_NN, axis=-1)

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, prediction_NN)
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = [f'{value}' for value in cm.flatten()]
group_percentages = [f'{value:.2f}' for value in cm.flatten()/np.sum(cm)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cm, annot=labels, fmt='', cmap='Reds')
# Out:
# 18/18 [==============================] - 4s 240ms/step
# [[272  16]
#  [ 39 240]]
# <AxesSubplot: >

# %%
#  RANDOM FOREST PART
#  Now, let us use features from convolutional network for RF
from sklearn.ensemble import RandomForestClassifier
RF_model = RandomForestClassifier(n_estimators = 50, random_state = 42)

X_for_RF = feature_extractor.predict(x_train) #This will be input to RF

# Train the model on training data
RF_model.fit(X_for_RF, y_train) #For sklearn no one hot encoding

#Send test data through same feature extractor process
X_test_feature = feature_extractor.predict(x_test)
#Now predict using the trained RF model. 
prediction_RF = RF_model.predict(X_test_feature)

#Print overall accuracy
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(y_test, prediction_RF))
# Out:
# 42/42 [==============================] - 11s 266ms/step
# 18/18 [==============================] - 5s 253ms/step
# Accuracy =  0.8977072310405644

# %%
#Confusion Matrix - verify accuracy of each class
cm = confusion_matrix(y_test, prediction_RF)
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = [f'{value}' for value in cm.flatten()]
group_percentages = [f'{value:.2f}' for value in cm.flatten()/np.sum(cm)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cm, annot=labels, fmt='', cmap='Reds')
# Out:
# <AxesSubplot: >

# %%
# Visualize 25 mistakes
error_idx = [i for i, rslt in enumerate(y_test) if (rslt + prediction_RF[i] == 1)]

fig, axs = plt.subplots(nrows=5, ncols=5, figsize=(12,12))

for i, j in [(i,j) for i in np.arange(5) for j in np.arange(5)]:
    if (5*i+j) < len(error_idx):
        idx = error_idx[5*i+j]
        axs[i,j].imshow(x_test[idx])
        axs[i,j].set_title(f'pred {int(prediction_RF[idx])}, real {int(y_test[idx])}')
        axs[i,j].axis('off')

plt.show()
