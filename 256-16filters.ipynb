# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import cv2
import csv
from keras.models import Model, Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from keras.layers.normalization import batch_normalization
import os
import seaborn as sns
# Out:
# 2023-04-05 21:08:33.983975: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Set up folder
SIZE = 256 #Size of the images this model will deal with

# %%
# Set up folder, unless it is already set up
p = os.path.abspath('.')
output_dir = os.path.join(p, f'{SIZE}')
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
    print(f"{output_dir} created")
else:
    print(f"{output_dir} already exists")
output_dir = output_dir

# Resize images and write them into folder, unless they are alrady there
for file in glob.glob('./Thresholded/*'):
	filename = file.split('/')[-1]
	new_name = os.path.join(output_dir, filename)
	if not os.path.exists(new_name):
		img = cv2.imread(file, cv2.IMREAD_COLOR)
		img = cv2.resize(img, (SIZE,SIZE))
		cv2.imwrite(new_name, img)

# Read filenames in the folder
image_names = []
labels = []

for file in glob.glob(f'{output_dir}/*.jpg'):
	filename = file.split('/')[-1]
	num_colonies = int(filename.split('-')[2].strip().split('.')[0])
	if num_colonies == 0:
		labels.append(0)
	else:
		labels.append(1)
	image_names.append(filename)

image_names = np.array(image_names) #  Array with image nbames
labels = np.array(labels)			#  Array with binary labels

#  Make two arrays with filenames: one for positive and one for negative images
pos_im_files = [image_names[i] for i in range(image_names.shape[0]) if labels[i]]
pos_im_files = np.array(pos_im_files)
neg_im_files = [image_names[i] for i in range(image_names.shape[0]) if not labels[i]]
neg_im_files = np.array(neg_im_files)
num_pos = pos_im_files.shape[0]
num_neg = neg_im_files.shape[0]
print(f'Full dataset: {num_pos} images with bacteria and {num_neg} without')

#  There are ~10x positive than negative.
#  For initital training let's get all positive and equal number of negative
#  For that:
#  (1) Index files of randomly selected negative images
np.random.seed(0) # For reproducibility
idx = np.random.choice(np.arange(neg_im_files.shape[0]), num_pos, replace = False)
#  (2) Apply this index to the array of image names
neg_selected_files = neg_im_files[idx]
#  (3) Make a full set of file names, with X and y, not split into train.test yet
X_files = np.concatenate((pos_im_files,neg_selected_files), axis =0)
y = np.concatenate((np.ones(num_pos), np.zeros(neg_selected_files.shape[0])))

print(f"Balanced dataset: X: {X_files.shape}, y: {y.shape}")
# Out:
# /home/art_usr/source_code/CFU_counter/256 created
# Full dataset: 315 images with bacteria and 3428 without
# Balanced dataset: X: (630,), y: (630,)

# %%
# Now shuffle the names
print("Suffling the dataset ....")
num_datapoints = X_files.shape[0]
indices = np.arange(num_datapoints)
shuffled_indices = np.random.permutation(indices)
X_shuffled_files = X_files[shuffled_indices]
y_shuffled = y[shuffled_indices]

# Read the actual files:
print("Reading actual images...")
images = []
for file_name in X_shuffled_files:
    file = os.path.join(output_dir, file_name)
    img = cv2.imread(file, cv2.IMREAD_COLOR)
    img = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
    images.append(img)

X_shuffled = np.array(images) # Shuffled dataset

# Split into test and train. 
# Rely on random shuffling, can just take first 70% for train
print("Splitting to train/test 70/30")
num_train = int(num_datapoints*0.7)

x_train = X_shuffled[ :num_train, : , : , : ]
y_train = y_shuffled[ :num_train]
x_test = X_shuffled[num_train: , : , : , : ]
y_test = y_shuffled[num_train: ]

print(f'Set shape: train-> {x_train.shape}, test ->{x_test.shape}')
# Out:
# Suffling the dataset ....
# Reading actual images...
# Splitting to train/test 70/30
# Set shape: train-> (441, 256, 256, 3), test ->(189, 256, 256, 3)

# %%
# Visualize first 25 images to make sure it makes sense
fig, axs = plt.subplots(nrows=5, ncols=5, figsize=(12,12))

row = 0
label_name = "Shirt predicted as coat"
axs[row,0].set_title(label_name)
axs[row,0].axis('off')

for i, j in [(i,j) for i in np.arange(5) for j in np.arange(5)]:
    idx = 5*i+j
    image = cv2.cvtColor(x_train[idx], cv2.COLOR_HSV2RGB)
    axs[i,j].imshow(image)
    axs[i,j].set_title(y_train[idx])
    axs[i,j].axis('off')

plt.show()

# %%
#Make convolutional layers

kernels = [ (np.max([int(SIZE*fraction), 3]),np.max([int(SIZE*fraction), 3])) for fraction in (0.01, 0.02, 0.04, 0.06)]

activation = 'sigmoid'

feature_extractor = Sequential()
feature_extractor.add(Conv2D(16, kernels[0], activation = activation, padding = 'same', input_shape = (SIZE, SIZE, 3)))
feature_extractor.add(batch_normalization.BatchNormalization())

for kernel in kernels[1:]:
    print(kernel)
    feature_extractor.add(Conv2D(16, kernel, activation = activation, padding = 'same', kernel_initializer = 'he_uniform'))
    feature_extractor.add(batch_normalization.BatchNormalization())
    feature_extractor.add(MaxPooling2D())

feature_extractor.add(Flatten())

#Add layers for deep learning prediction
x = feature_extractor.output  
x = Dense(128, activation = activation, kernel_initializer = 'he_uniform')(x)
prediction_layer = Dense(2, activation = 'softmax')(x)

# Make a new model combining both feature extractor and x
cnn_model = Model(inputs=feature_extractor.input, outputs=prediction_layer)
cnn_model.compile(optimizer='rmsprop',loss = 'categorical_crossentropy', metrics = ['accuracy'])
print(cnn_model.summary())
# Out:
# 2023-04-05 21:11:28.437936: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-05 21:11:28.449160: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# (5, 5)
# (10, 10)
# (15, 15)
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_input (InputLayer)   [(None, 256, 256, 3)]     0
#
#  conv2d (Conv2D)             (None, 256, 256, 16)      448
#
#  batch_normalization (BatchN  (None, 256, 256, 16)     64
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 16)      6416
#
#  batch_normalization_1 (Batc  (None, 256, 256, 16)     64
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 16)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 16)      25616
#
#  batch_normalization_2 (Batc  (None, 128, 128, 16)     64
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 16)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 16)        57616
#
#  batch_normalization_3 (Batc  (None, 64, 64, 16)       64
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 128)               2097280
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 2,187,890
# Trainable params: 2,187,762
# Non-trainable params: 128
# _________________________________________________________________
# None

# %%
from tensorflow.keras.callbacks import Callback

class EarlyStoppingAtAccuracy(Callback):
    def __init__(self, threshold, acc_hist):
        super(EarlyStoppingAtAccuracy, self).__init__()
        self.threshold = threshold
        self.acc_hist = acc_hist

    def on_epoch_end(self, epoch, logs=None):
        val_accuracy = logs.get("val_accuracy")
        self.acc_hist.append(val_accuracy)
        if len(self.acc_hist) > 3 and np.median(self.acc_hist[-2:]) >= self.threshold:
            self.model.stop_training = True
            print(f"\nStopping training: Validation accuracy reached {self.threshold:.2f}")

# Set the desired accuracy threshold
accuracy_threshold = 0.85
acc_hist = []

# Create the early stopping callback
early_stopping = EarlyStoppingAtAccuracy(accuracy_threshold, acc_hist )


#Convert y to one hot encoding for use in CNN 
from keras.utils import to_categorical
y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)

# Train CNN model
history = cnn_model.fit(x_train, y_train_one_hot, epochs=100, validation_data = (x_test, y_test_one_hot), callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 14/14 [==============================] - 155s 11s/step - loss: 0.4662 - accuracy: 0.7800 - val_loss: 0.5646 - val_accuracy: 0.7566
# Epoch 2/100
# 14/14 [==============================] - 158s 11s/step - loss: 0.4367 - accuracy: 0.8005 - val_loss: 0.7910 - val_accuracy: 0.5291
# Epoch 3/100
# 14/14 [==============================] - 158s 11s/step - loss: 0.4254 - accuracy: 0.8118 - val_loss: 0.7748 - val_accuracy: 0.6508
# Epoch 4/100
# 14/14 [==============================] - 157s 11s/step - loss: 0.4512 - accuracy: 0.8050 - val_loss: 0.6065 - val_accuracy: 0.6825
# Epoch 5/100
# 14/14 [==============================] - 156s 11s/step - loss: 0.4430 - accuracy: 0.8005 - val_loss: 0.7163 - val_accuracy: 0.5450
# Epoch 6/100
# 14/14 [==============================] - 151s 11s/step - loss: 0.4327 - accuracy: 0.7891 - val_loss: 0.5456 - val_accuracy: 0.7302
# Epoch 7/100
# 14/14 [==============================] - 147s 11s/step - loss: 0.4584 - accuracy: 0.7800 - val_loss: 0.5933 - val_accuracy: 0.6931
# Epoch 8/100
# 14/14 [==============================] - 146s 11s/step - loss: 0.3991 - accuracy: 0.8254 - val_loss: 0.5325 - val_accuracy: 0.7354
# Epoch 9/100
# 14/14 [==============================] - 149s 11s/step - loss: 0.3951 - accuracy: 0.8367 - val_loss: 0.6162 - val_accuracy: 0.6667
# Epoch 10/100
# 14/14 [==============================] - 152s 11s/step - loss: 0.4017 - accuracy: 0.8231 - val_loss: 0.6209 - val_accuracy: 0.6984
# Epoch 11/100
# 14/14 [==============================] - 148s 11s/step - loss: 0.4122 - accuracy: 0.8050 - val_loss: 0.5865 - val_accuracy: 0.6614
# Epoch 12/100
# 14/14 [==============================] - 149s 11s/step - loss: 0.4079 - accuracy: 0.8005 - val_loss: 0.5595 - val_accuracy: 0.7354
# Epoch 13/100
# 14/14 [==============================] - 153s 11s/step - loss: 0.3901 - accuracy: 0.8254 - val_loss: 0.5588 - val_accuracy: 0.7037
# Epoch 14/100
# 14/14 [==============================] - 148s 11s/step - loss: 0.3803 - accuracy: 0.8209 - val_loss: 0.5353 - val_accuracy: 0.7354
# Epoch 15/100
# 14/14 [==============================] - 154s 11s/step - loss: 0.3614 - accuracy: 0.8526 - val_loss: 0.5359 - val_accuracy: 0.7460
# Epoch 16/100
# 14/14 [==============================] - 148s 11s/step - loss: 0.3951 - accuracy: 0.8073 - val_loss: 0.5696 - val_accuracy: 0.6931
# Epoch 17/100
# 14/14 [==============================] - 148s 11s/step - loss: 0.3844 - accuracy: 0.8390 - val_loss: 0.5969 - val_accuracy: 0.7037
# Epoch 18/100
# 14/14 [==============================] - 147s 11s/step - loss: 0.3371 - accuracy: 0.8503 - val_loss: 0.6071 - val_accuracy: 0.7196
# Epoch 19/100
# 14/14 [==============================] - 148s 11s/step - loss: 0.3183 - accuracy: 0.8594 - val_loss: 0.5794 - val_accuracy: 0.7037
# Epoch 20/100
# 14/14 [==============================] - 148s 11s/step - loss: 0.3560 - accuracy: 0.8345 - val_loss: 0.6816 - val_accuracy: 0.7143
# Epoch 21/100
# 14/14 [==============================] - 148s 11s/step - loss: 0.3629 - accuracy: 0.8639 - val_loss: 0.5233 - val_accuracy: 0.7513
# Epoch 22/100
# 14/14 [==============================] - 146s 11s/step - loss: 0.3054 - accuracy: 0.8844 - val_loss: 0.5880 - val_accuracy: 0.7566
# Epoch 23/100
# 14/14 [==============================] - 146s 11s/step - loss: 0.3093 - accuracy: 0.8685 - val_loss: 0.5347 - val_accuracy: 0.7619
# Epoch 24/100
# 14/14 [==============================] - 147s 11s/step - loss: 0.3143 - accuracy: 0.8617 - val_loss: 0.6693 - val_accuracy: 0.6455
# Epoch 25/100
# 14/14 [==============================] - 147s 11s/step - loss: 0.2808 - accuracy: 0.8866 - val_loss: 0.6412 - val_accuracy: 0.7460
# Epoch 26/100
# 14/14 [==============================] - 152s 11s/step - loss: 0.3192 - accuracy: 0.8776 - val_loss: 0.5779 - val_accuracy: 0.7249
# Epoch 27/100
# 14/14 [==============================] - 152s 11s/step - loss: 0.2896 - accuracy: 0.8776 - val_loss: 0.6122 - val_accuracy: 0.7460
# Epoch 28/100
# 14/14 [==============================] - 148s 11s/step - loss: 0.2979 - accuracy: 0.8617 - val_loss: 0.6041 - val_accuracy: 0.7566
# Epoch 29/100
# 14/14 [==============================] - 146s 10s/step - loss: 0.2674 - accuracy: 0.9002 - val_loss: 0.6258 - val_accuracy: 0.6614
# Epoch 30/100
# 14/14 [==============================] - 155s 11s/step - loss: 0.2908 - accuracy: 0.8685 - val_loss: 0.5330 - val_accuracy: 0.7407
# Epoch 31/100
# 14/14 [==============================] - 147s 11s/step - loss: 0.2744 - accuracy: 0.8821 - val_loss: 0.6964 - val_accuracy: 0.7196
# Epoch 32/100
# 14/14 [==============================] - 156s 11s/step - loss: 0.2981 - accuracy: 0.8639 - val_loss: 0.6476 - val_accuracy: 0.7196
# Epoch 33/100
# 14/14 [==============================] - 151s 11s/step - loss: 0.2582 - accuracy: 0.8934 - val_loss: 0.6326 - val_accuracy: 0.7143
# Epoch 34/100
# 14/14 [==============================] - 151s 11s/step - loss: 0.2620 - accuracy: 0.8844 - val_loss: 0.5826 - val_accuracy: 0.7143
# Epoch 35/100
# 14/14 [==============================] - 148s 11s/step - loss: 0.2422 - accuracy: 0.9048 - val_loss: 0.5287 - val_accuracy: 0.7619
# Epoch 36/100
# 14/14 [==============================] - 147s 11s/step - loss: 0.2382 - accuracy: 0.9206 - val_loss: 0.5897 - val_accuracy: 0.7566
# Epoch 37/100
# 14/14 [==============================] - 148s 11s/step - loss: 0.2164 - accuracy: 0.9274 - val_loss: 0.6874 - val_accuracy: 0.7090
# Epoch 38/100
# 14/14 [==============================] - 146s 11s/step - loss: 0.2287 - accuracy: 0.9161 - val_loss: 0.5523 - val_accuracy: 0.7460
# Epoch 39/100
# 14/14 [==============================] - 151s 11s/step - loss: 0.1973 - accuracy: 0.9274 - val_loss: 0.6646 - val_accuracy: 0.7302
# Epoch 40/100
# 14/14 [==============================] - 149s 11s/step - loss: 0.2579 - accuracy: 0.8957 - val_loss: 0.5838 - val_accuracy: 0.7460
# Epoch 41/100
# 14/14 [==============================] - 147s 11s/step - loss: 0.2030 - accuracy: 0.9161 - val_loss: 0.5741 - val_accuracy: 0.7566
# Epoch 42/100
# 14/14 [==============================] - 148s 11s/step - loss: 0.1892 - accuracy: 0.9252 - val_loss: 0.5691 - val_accuracy: 0.7513
# Epoch 43/100
# 14/14 [==============================] - 147s 11s/step - loss: 0.1986 - accuracy: 0.9229 - val_loss: 0.5266 - val_accuracy: 0.7407
# Epoch 44/100
# 14/14 [==============================] - 150s 11s/step - loss: 0.2397 - accuracy: 0.9138 - val_loss: 0.6036 - val_accuracy: 0.7460
# Epoch 45/100
# 14/14 [==============================] - 147s 11s/step - loss: 0.2229 - accuracy: 0.9229 - val_loss: 0.6014 - val_accuracy: 0.7460
# Epoch 46/100
# 14/14 [==============================] - 146s 11s/step - loss: 0.1805 - accuracy: 0.9388 - val_loss: 0.5423 - val_accuracy: 0.7513
# Epoch 47/100
# 14/14 [==============================] - 148s 11s/step - loss: 0.1614 - accuracy: 0.9456 - val_loss: 0.5866 - val_accuracy: 0.7249
# Epoch 48/100
# 14/14 [==============================] - 147s 11s/step - loss: 0.1656 - accuracy: 0.9342 - val_loss: 0.5610 - val_accuracy: 0.7672
# Epoch 49/100
# 14/14 [==============================] - 147s 11s/step - loss: 0.1591 - accuracy: 0.9524 - val_loss: 0.5900 - val_accuracy: 0.7460
# Epoch 50/100
# 14/14 [==============================] - 148s 11s/step - loss: 0.1719 - accuracy: 0.9388 - val_loss: 1.2574 - val_accuracy: 0.6349
# Epoch 51/100
# 14/14 [==============================] - 148s 11s/step - loss: 0.1857 - accuracy: 0.9297 - val_loss: 0.6112 - val_accuracy: 0.7460
# Epoch 52/100
# 14/14 [==============================] - 147s 11s/step - loss: 0.1399 - accuracy: 0.9524 - val_loss: 0.5802 - val_accuracy: 0.7566
# Epoch 53/100
# 14/14 [==============================] - 148s 11s/step - loss: 0.3112 - accuracy: 0.9184 - val_loss: 0.8857 - val_accuracy: 0.7143
# Epoch 54/100
# 14/14 [==============================] - 146s 11s/step - loss: 0.1425 - accuracy: 0.9456 - val_loss: 0.5756 - val_accuracy: 0.7249
# Epoch 55/100
# 14/14 [==============================] - 147s 11s/step - loss: 0.1325 - accuracy: 0.9683 - val_loss: 0.6308 - val_accuracy: 0.7143
# Epoch 56/100
# 14/14 [==============================] - 146s 11s/step - loss: 0.1599 - accuracy: 0.9456 - val_loss: 0.5539 - val_accuracy: 0.7196
# Epoch 57/100
# 14/14 [==============================] - 148s 11s/step - loss: 0.1801 - accuracy: 0.9365 - val_loss: 0.6003 - val_accuracy: 0.7460
# Epoch 58/100
# 14/14 [==============================] - 150s 11s/step - loss: 0.1296 - accuracy: 0.9592 - val_loss: 0.6572 - val_accuracy: 0.7513
# Epoch 59/100
# 14/14 [==============================] - 146s 11s/step - loss: 0.1358 - accuracy: 0.9592 - val_loss: 0.6314 - val_accuracy: 0.7725
# Epoch 60/100
# 14/14 [==============================] - 147s 11s/step - loss: 0.1300 - accuracy: 0.9546 - val_loss: 0.5704 - val_accuracy: 0.7460
# Epoch 61/100
# 14/14 [==============================] - 146s 11s/step - loss: 0.1243 - accuracy: 0.9637 - val_loss: 0.6616 - val_accuracy: 0.7460
# Epoch 62/100
# 14/14 [==============================] - 148s 11s/step - loss: 0.1334 - accuracy: 0.9592 - val_loss: 0.6370 - val_accuracy: 0.7460
# Epoch 63/100
# 14/14 [==============================] - 145s 11s/step - loss: 0.1056 - accuracy: 0.9751 - val_loss: 0.6017 - val_accuracy: 0.7196
# Epoch 64/100
# 14/14 [==============================] - 155s 11s/step - loss: 0.1352 - accuracy: 0.9501 - val_loss: 0.6268 - val_accuracy: 0.7513
# Epoch 65/100
# 14/14 [==============================] - 165s 12s/step - loss: 0.1043 - accuracy: 0.9751 - val_loss: 0.5864 - val_accuracy: 0.7672
# Epoch 66/100
# 14/14 [==============================] - 162s 12s/step - loss: 0.0951 - accuracy: 0.9773 - val_loss: 0.8063 - val_accuracy: 0.7249
# Epoch 67/100
# 14/14 [==============================] - 162s 12s/step - loss: 0.1117 - accuracy: 0.9660 - val_loss: 0.8646 - val_accuracy: 0.7037
# Epoch 68/100
# 14/14 [==============================] - 162s 12s/step - loss: 0.1158 - accuracy: 0.9592 - val_loss: 0.5974 - val_accuracy: 0.7513
# Epoch 69/100
# 14/14 [==============================] - 163s 12s/step - loss: 0.0733 - accuracy: 0.9887 - val_loss: 0.7023 - val_accuracy: 0.7090
# Epoch 70/100
# 14/14 [==============================] - 164s 12s/step - loss: 0.0756 - accuracy: 0.9796 - val_loss: 0.7707 - val_accuracy: 0.7513
# Epoch 71/100
# 14/14 [==============================] - 162s 12s/step - loss: 0.0886 - accuracy: 0.9773 - val_loss: 0.5798 - val_accuracy: 0.7460
# Epoch 72/100
# 14/14 [==============================] - 163s 12s/step - loss: 0.1130 - accuracy: 0.9592 - val_loss: 0.7215 - val_accuracy: 0.7460
# Epoch 73/100
# 14/14 [==============================] - 164s 12s/step - loss: 0.0894 - accuracy: 0.9660 - val_loss: 0.9402 - val_accuracy: 0.6984
# Epoch 74/100
# 14/14 [==============================] - 164s 12s/step - loss: 0.0752 - accuracy: 0.9796 - val_loss: 0.8559 - val_accuracy: 0.7143
# Epoch 75/100
# 14/14 [==============================] - 166s 12s/step - loss: 0.0621 - accuracy: 0.9864 - val_loss: 0.7137 - val_accuracy: 0.7407
# Epoch 76/100
# 14/14 [==============================] - 164s 12s/step - loss: 0.0598 - accuracy: 0.9819 - val_loss: 0.6652 - val_accuracy: 0.7566
# Epoch 77/100
# 14/14 [==============================] - 167s 12s/step - loss: 0.0667 - accuracy: 0.9864 - val_loss: 0.7172 - val_accuracy: 0.7513
# Epoch 78/100
# 14/14 [==============================] - 166s 12s/step - loss: 0.0586 - accuracy: 0.9887 - val_loss: 0.7811 - val_accuracy: 0.7354
# Epoch 79/100
# 14/14 [==============================] - 162s 12s/step - loss: 0.1034 - accuracy: 0.9660 - val_loss: 0.6840 - val_accuracy: 0.7566
# Epoch 80/100
# 14/14 [==============================] - 166s 12s/step - loss: 0.0397 - accuracy: 0.9955 - val_loss: 0.8125 - val_accuracy: 0.7460
# Epoch 81/100
# 14/14 [==============================] - 166s 12s/step - loss: 0.0675 - accuracy: 0.9796 - val_loss: 0.8007 - val_accuracy: 0.7354
# Epoch 82/100
# 14/14 [==============================] - 161s 12s/step - loss: 0.0630 - accuracy: 0.9864 - val_loss: 1.0714 - val_accuracy: 0.6878
# Epoch 83/100
# 14/14 [==============================] - 163s 12s/step - loss: 0.0618 - accuracy: 0.9819 - val_loss: 1.0859 - val_accuracy: 0.7196
# Epoch 84/100
# 14/14 [==============================] - 162s 12s/step - loss: 0.0438 - accuracy: 0.9887 - val_loss: 0.7248 - val_accuracy: 0.7566
# Epoch 85/100
# 14/14 [==============================] - 174s 13s/step - loss: 0.0487 - accuracy: 0.9841 - val_loss: 0.8535 - val_accuracy: 0.7460
# Epoch 86/100
# 14/14 [==============================] - 160s 12s/step - loss: 0.0826 - accuracy: 0.9705 - val_loss: 0.8943 - val_accuracy: 0.6667
# Epoch 87/100
# 14/14 [==============================] - 164s 12s/step - loss: 0.0320 - accuracy: 0.9955 - val_loss: 0.9003 - val_accuracy: 0.7302
# Epoch 88/100
# 14/14 [==============================] - 165s 12s/step - loss: 0.0448 - accuracy: 0.9841 - val_loss: 0.9894 - val_accuracy: 0.7090
# Epoch 89/100
# 14/14 [==============================] - 162s 12s/step - loss: 0.0385 - accuracy: 0.9887 - val_loss: 0.8254 - val_accuracy: 0.7249
# Epoch 90/100
# 14/14 [==============================] - 162s 12s/step - loss: 0.0287 - accuracy: 0.9955 - val_loss: 0.8695 - val_accuracy: 0.7354
# Epoch 91/100
# 14/14 [==============================] - 167s 12s/step - loss: 0.0388 - accuracy: 0.9977 - val_loss: 0.7636 - val_accuracy: 0.7460
# Epoch 92/100
# 14/14 [==============================] - 165s 12s/step - loss: 0.1121 - accuracy: 0.9705 - val_loss: 1.1113 - val_accuracy: 0.7143
# Epoch 93/100
# 14/14 [==============================] - 161s 12s/step - loss: 0.0518 - accuracy: 0.9864 - val_loss: 0.7790 - val_accuracy: 0.7302
# Epoch 94/100
# 14/14 [==============================] - 162s 12s/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.7455 - val_accuracy: 0.7725
# Epoch 95/100
# 14/14 [==============================] - 161s 12s/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.7445 - val_accuracy: 0.7566
# Epoch 96/100
# 14/14 [==============================] - 164s 12s/step - loss: 0.0176 - accuracy: 0.9977 - val_loss: 0.9364 - val_accuracy: 0.7407
# Epoch 97/100
# 14/14 [==============================] - 164s 12s/step - loss: 0.0679 - accuracy: 0.9819 - val_loss: 0.7080 - val_accuracy: 0.7831
# Epoch 98/100
# 14/14 [==============================] - 164s 12s/step - loss: 0.0578 - accuracy: 0.9819 - val_loss: 0.7696 - val_accuracy: 0.7619
# Epoch 99/100
# 14/14 [==============================] - 164s 12s/step - loss: 0.0360 - accuracy: 0.9909 - val_loss: 0.8317 - val_accuracy: 0.7672
# Epoch 100/100
# 14/14 [==============================] - 164s 12s/step - loss: 0.0228 - accuracy: 0.9977 - val_loss: 0.8051 - val_accuracy: 0.7725

# %%
# Set up folder, unless it is already set up
p = os.path.abspath('.')
model_dir = os.path.join(p, f'{SIZE}','model')
if not os.path.exists(model_dir):
    os.mkdir(model_dir)
    print(f"{model_dir} created")
else:
    print(f"{model_dir} already exists")

cnn_model.save(model_dir)
# Out:
# /home/art_usr/source_code/CFU_counter/256/model already exists
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/art_usr/source_code/CFU_counter/256/model/assets
# INFO:tensorflow:Assets written to: /home/art_usr/source_code/CFU_counter/256/model/assets

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12,6))
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
axs[0].set_title('Loss')
axs[0].scatter(epochs, loss, label = 'Training loss')
axs[0].scatter(epochs, val_loss, label = 'Validation loss')
axs[0].legend()
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Loss')
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
axs[1].set_title('Accuracy')
axs[1].scatter(epochs, accuracy, label = 'Training accuracy')
axs[1].scatter(epochs, val_accuracy, label = 'Validation accuracy')
axs[1].legend()
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Loss')


plt.show()

# %%
prediction_NN = cnn_model.predict(x_test)
prediction_NN = np.argmax(prediction_NN, axis=-1)

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, prediction_NN)
print(cm)
sns.heatmap(cm, annot=True)
# Out:
# 6/6 [==============================] - 18s 3s/step
# [[97  6]
#  [37 49]]
# <AxesSubplot: >

# %%
# Save results into a csv
csv_path = os.path.join(output_dir, 'cnn_metrics.csv')
with open(csv_path, 'w+') as file:
  csvwriter = csv.writer(file)
  csvwriter.writerow('val_loss')
  csvwriter.writerow(history.history['val_loss'])
  csvwriter.writerow('loss')
  csvwriter.writerow(history.history['loss'])
  csvwriter.writerow('val_accuracy')
  csvwriter.writerow(history.history['val_accuracy'])
  csvwriter.writerow('accuracy')
  csvwriter.writerow(history.history['accuracy'])
  csvwriter.writerow(cm[0])
  csvwriter.writerow(cm[1])

# %%
#  RANDOM FOREST PART
#  Now, let us use features from convolutional network for RF
from sklearn.ensemble import RandomForestClassifier
RF_model = RandomForestClassifier(n_estimators = 50, random_state = 42)

X_for_RF = feature_extractor.predict(x_train) #This will be input to RF

# Train the model on training data
RF_model.fit(X_for_RF, y_train) #For sklearn no one hot encoding

#Send test data through same feature extractor process
X_test_feature = feature_extractor.predict(x_test)
#Now predict using the trained RF model. 
prediction_RF = RF_model.predict(X_test_feature)

#Print overall accuracy
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(y_test, prediction_RF))
# Out:
# 14/14 [==============================] - 45s 3s/step
# 6/6 [==============================] - 26s 5s/step
# Accuracy =  0.7777777777777778

# %%
#Confusion Matrix - verify accuracy of each class
cm = confusion_matrix(y_test, prediction_RF)
print(cm)
sns.heatmap(cm, annot=True)
# Out:
# [[84 19]
#  [23 63]]
# <AxesSubplot: >

# %%
# Visualize 25 mistakes
error_idx = [i for i, rslt in enumerate(y_test) if (rslt + prediction_RF[i] == 1)]

fig, axs = plt.subplots(nrows=5, ncols=5, figsize=(12,12))

for i, j in [(i,j) for i in np.arange(5) for j in np.arange(5)]:
    idx = error_idx[5*i+j]
    image = cv2.cvtColor(x_test[idx], cv2.COLOR_HSV2RGB)
    axs[i,j].imshow(image)
    axs[i,j].set_title(f'pred {int(prediction_RF[idx])}, real {int(y_test[idx])}')
    axs[i,j].axis('off')

plt.show()
